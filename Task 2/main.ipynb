# %% [markdown]
# This project is a part of internship program offered to me by **CODSOFT** for their 4 week internship program. This is Task 2 of the internship program.
#
# Name: Chirag
#
# University: Chandigarh University

# %% [markdown]
# **Step 1: Importing the required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# **Step 2: Importing data saved as csv file**

# %%
car_purchasing = pd.read_csv(r"car_purchasing.csv", encoding = "ISO-8859-1")

# %%
car_purchasing.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %% [markdown]
# **Step 3: Get each and every details of the data**
#
# 1. Check number of rows and column in the dataset.
# 2. Getting the data types of every column
# 3. To check is there any null values in the dataset

# %%
car_purchasing.shape
# Out:
# (500, 9)

# %%
car_purchasing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
car_purchasing.isnull().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %% [markdown]
# **Step 4: Data Pre-processing**
#
# 1. Removing or cleaning dataset with null values.
# 2. Decribing dataset.
# 3. Making data ready for analysis and visualization.

# %%
#Note that there is no null value in the column, So we don't need to fill mising values

# %%
#Also there is column of no use.
#Drop the column customer name, customer e-mail from the dataset
car_purchasing = car_purchasing.drop(columns="customer e-mail", axis = 1)
car_purchasing = car_purchasing.drop(columns="customer name", axis = 1)

# %%
car_purchasing.head()
# Out:
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
car_purchasing.isnull().sum()
# Out:
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
#Our data does not contain any null values now.
#Now we will describe the data and get simple results like mean, median, etc.
car_purchasing.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %% [markdown]
# **Note:**
#
# 1. We have cleaned the data and now it is ready for vizualization and Analysis.
# 2. We have removed the unnecessary columns and in necessary columns, replace the null values with the average values.

# %% [markdown]
# **Step 5: Data vizualization**

# %%
import matplotlib
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] =8
matplotlib.rcParams['figure.figsize'] = (10,6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# Plot 1: Distribution of Car Purchase Amount
plt.figure(figsize=(12, 6))
sns.histplot(car_purchasing['car purchase amount'], bins=30, kde=True)
plt.title('Distribution of Car Purchase Amount')
plt.xlabel('Car Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot 2: Gender distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=car_purchasing)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Plot 3: Age distribution
plt.figure(figsize=(12, 6))
sns.histplot(car_purchasing['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot 4: Annual Salary vs. Car Purchase Amount
plt.figure(figsize=(12, 6))
sns.scatterplot(x='annual Salary', y='car purchase amount', data=car_purchasing)
plt.title('Annual Salary vs. Car Purchase Amount')
plt.xlabel('Annual Salary')
plt.ylabel('Car Purchase Amount')
plt.show()

# %%
# Plot 5: Credit Card Debt distribution
plt.figure(figsize=(12, 6))
sns.histplot(car_purchasing['credit card debt'], bins=20, kde=True)
plt.title('Credit Card Debt Distribution')
plt.xlabel('Credit Card Debt')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot 6: Net Worth vs. Car Purchase Amount
plt.figure(figsize=(12, 6))
sns.scatterplot(x='net worth', y='car purchase amount', data=car_purchasing)
plt.title('Net Worth vs. Car Purchase Amount')
plt.xlabel('Net Worth')
plt.ylabel('Car Purchase Amount')
plt.show()

# %%
top_countries = car_purchasing['country'].value_counts().nlargest(20)

plt.figure(figsize=(14, 8))
sns.barplot(x=top_countries.index, y=top_countries.values, order=top_countries.index)
plt.title('Top 20 Country Distribution (Descending Order)')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Plot 8: Box plot of Car Purchase Amount by Gender
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='car purchase amount', data=car_purchasing)
plt.title('Box plot of Car Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Car Purchase Amount')
plt.show()

# %%
# Plot 9: Pair plot for selected numerical columns
sns.pairplot(car_purchasing[['age', 'annual Salary', 'credit card debt', 'net worth', 'car purchase amount']])
plt.suptitle('Pair Plot of Selected Numerical Columns', y=1.02)
plt.show()

# %%
# Plot 10: Correlation heatmap
correlation_matrix = car_purchasing.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\chira\AppData\Local\Temp\ipykernel_19864\1193481100.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = car_purchasing.corr()

# %% [markdown]
# **Step 6: Creating prediction Model**
#
# 1. Split the data in terms of independent variable and dependent variable.
# 2. Split the data into training and testing data
# 3. Train the model using Linear regression
# 4. Check accuracy

# %%
#Step 1: Splitting data into independent and dependent variable
#As we see in correlation map, price only depends upon age, annual salary and net worth so
#the code is as follows:
# Selecting columns for prediction
selected_columns = ['age', 'net worth', 'annual Salary', 'car purchase amount']
selected_data = car_purchasing[selected_columns]
# Split the data into features (X) and target variable (y)
X = selected_data[['age', 'net worth', 'annual Salary']]
Y = selected_data['car purchase amount']

# %%
X.head()
# Out:
#          age    net worth  annual Salary
# 0  41.851720  238961.2505    62812.09301
# 1  40.870623  530973.9078    66646.89292
# 2  43.152897  638467.1773    53798.55112
# 3  58.271369  548599.0524    79370.03798
# 4  57.313749  560304.0671    59729.15130

# %%
Y.head()
# Out:
# 0    35321.45877
# 1    45115.52566
# 2    42925.70921
# 3    67422.36313
# 4    55915.46248
# Name: car purchase amount, dtype: float64

# %%
#Step 2: Splitting the data into training and testing data set.
#We know best split method is 80 - 20 rule.
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#            age    net worth  annual Salary
# 5    56.824893  428485.3604    68499.85162
# 116  43.031069  325701.4083    69175.19403
# 45   55.275143  853913.8532    70787.27764
# 16   44.742200  370356.2223    63259.87837
# 462  39.141035  556945.8742    66680.27410

# %%
X_test.head()
# Out:
#            age    net worth  annual Salary
# 361  36.126918  551344.3365    74420.10254
# 73   47.789729  473845.8546    59139.21080
# 374  57.134576  657178.4135    67752.38329
# 155  50.219573   20000.0000    55381.53225
# 104  48.476396  891439.8761    63975.06090

# %%
Y_train.head()
# Out:
# 5      56611.99784
# 116    42408.02625
# 45     68925.09447
# 16     41814.72067
# 462    44430.63323
# Name: car purchase amount, dtype: float64

# %%
Y_test.head()
# Out:
# 361    46082.80993
# 73     45058.89690
# 374    63079.84329
# 155    31837.22537
# 104    60461.24268
# Name: car purchase amount, dtype: float64

# %%
#Step 3: Linear Regression Model

#Import libraries
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

#Create a model
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Step 4: Make predictions on the test set
y_pred = model.predict(X_test)

# %%
#Step 5: Evaluate the model
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared Value: {r2:.2f}')
# Out:
# Mean Squared Error: 2.01
# R-squared Value: 1.00

# %%
#Step 6 Plot the predicted vs. actual values
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, y_pred)
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)], linestyle='--', color='red', linewidth=2)
plt.title('Actual vs. Predicted Car Purchase Amount')
plt.xlabel('Actual Car Purchase Amount')
plt.ylabel('Predicted Car Purchase Amount')
plt.show()

# %% [markdown]
# ## Hence our data is now transformed in a prediction model as we have tested the dataset and checked for accuracy.

# %%
#Converting model into prediction model

# %%
from joblib import dump, load
dump(model, 'main.joblib')
# Out:
# ['main.joblib']
